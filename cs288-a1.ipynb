# %% [markdown]
# <a href="https://colab.research.google.com/github/Chang-Han-Chen/Chang-Han-Chen.github.io/blob/master/cs288-a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repo
# !git clone https://github.com/akshat57/cs288-sp26-a1.git

# Go to Part2
# %cd cs288-sp26-a1/Part2

# Quick sanity check
# !ls -la
# Out:
# Cloning into 'cs288-sp26-a1'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 57 (delta 3), reused 2 (delta 2), pack-reused 46 (from 1)
# Receiving objects: 100% (57/57), 19.27 MiB | 23.55 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/cs288-sp26-a1/Part2
# total 68
# drwxr-xr-x 5 root root 4096 Feb 13 07:03 .
# drwxr-xr-x 5 root root 4096 Feb 13 07:03 ..
# drwxr-xr-x 4 root root 4096 Feb 13 07:03 data
# -rw-r--r-- 1 root root 1717 Feb 13 07:03 features.py
# -rw-r--r-- 1 root root  169 Feb 13 07:03 .gitignore
# -rw-r--r-- 1 root root 8215 Feb 13 07:03 multilayer_perceptron.py
# -rw-r--r-- 1 root root 5716 Feb 13 07:03 perceptron.py
# -rw-r--r-- 1 root root    9 Feb 13 07:03 pytest.ini
# -rw-r--r-- 1 root root 1018 Feb 13 07:03 README.md
# -rw-r--r-- 1 root root   30 Feb 13 07:03 requirements.txt
# drwxr-xr-x 2 root root 4096 Feb 13 07:03 results
# ...

# %%
# Install requirements if present
# !python -m pip install -q --upgrade pip

# Try common locations
# !test -f requirements.txt && pip -q install -r requirements.txt || true
# !test -f ../requirements.txt && pip -q install -r ../requirements.txt || true

# %%
import os, sys
sys.path.insert(0, os.path.abspath("."))  # Part2 on PYTHONPATH

# %%
# !pytest -q
# Out:
# ....................                                                     [100%]
# 20 passed in 2.88s

# %%
# !python perceptron.py -d newsgroups -f bow
# !python perceptron.py -d sst2 -f bow
# !python multilayer_perceptron.py -d newsgroups
# Out:
# Training the model...
# Saved results to results/perceptron_newsgroups_bow_dev_predictions.csv
# Development accuracy: 84.22%
# Saved results to results/perceptron_newsgroups_test_predictions.csv
# Model weights saved to results/perceptron_newsgroups_bow_model.json
# Training the model...
# Saved results to results/perceptron_sst2_bow_dev_predictions.csv
# Development accuracy: 74.74%
# Saved results to results/perceptron_sst2_test_predictions.csv
# Model weights saved to results/perceptron_sst2_bow_model.json
# Id to label mapping:
# {0: 'alt.atheism',
#  1: 'comp.graphics',
#  2: 'comp.os.ms-windows.misc',
#  3: 'comp.sys.ibm.pc.hardware',
#  4: 'comp.sys.mac.hardware',
#  5: 'comp.windows.x',
#  6: 'misc.forsale',
#  7: 'rec.autos',
#  8: 'rec.motorcycles',
#  9: 'rec.sport.baseball',
#  10: 'rec.sport.hockey',
#  11: 'sci.crypt',
#  12: 'sci.electronics',
#  13: 'sci.med',
#  14: 'sci.space',
#  15: 'soc.religion.christian',
#  16: 'talk.politics.guns',
# ...
